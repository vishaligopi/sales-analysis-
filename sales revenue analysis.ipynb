# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_excel("/content/Customer_Segmentation_Dataset.xlsx")
df.head()
# Out:
#    CustomerID  Age  Income  SpendingScore  PurchaseFrequency  Gender Region
# 0           1   56   72733             36                  9    Male  South
# 1           2   46   85318             45                  7    Male   West
# 2           3   32  109474             20                 12  Female   East
# 3           4   60   43664             65                 14    Male  South
# 4           5   25   87172              8                  4    Male   West

# %%
X = df[['Income','SpendingScore']]
kmeans = KMeans(n_clusters=4)
df['Cluster'] = kmeans.fit_predict(X)

# %%
plt.scatter(df['Income'], df['SpendingScore'], c=df['Cluster'])
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.show()
